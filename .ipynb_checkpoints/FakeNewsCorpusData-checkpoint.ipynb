# %%
import pandas as pd

# %%
df = pd.read_csv('995,000_rows.csv', chunksize=1000)

# %%
for chunk in df:
    display(chunk.head(10))
    break
# Out:
#        Unnamed: 0         id                   domain        type  \
# 15000         858  9730198.0              nytimes.com    reliable
# 15001        3875  9272937.0              nytimes.com    reliable
# 15002        1810  3216416.0     naturalnewsblogs.com     junksci
# 15003        5823  4726448.0  investmentwatchblog.com        bias
# 15004          95  5063749.0         www.ammoland.com         NaN
# 15005        7615  8456674.0              nytimes.com    reliable
# 15006        2529  2085895.0          sputniknews.com        bias
# 15007        9090  3668684.0        beforeitsnews.com        fake
# 15008        7446  1187930.0            wikileaks.org  unreliable
# 15009        2726  8911785.0              nytimes.com    reliable
#
#                                                      url  \
# 15000  https://query.nytimes.com/gst/fullpage.html?re...
# 15001  https://www.nytimes.com/2009/09/27/books/revie...
# 15002  https://www.naturalnewsblogs.com/author/foodme...
# ...

# %%
for chunk in df:
    look = chunk[['type', 'source']]
    display(look.head(60))
    break
# Out:
#              type   source
# 16000     unknown      NaN
# 16001  conspiracy      NaN
# 16002       rumor      NaN
# 16003        bias      NaN
# 16004        fake      NaN
# 16005    reliable  nytimes
# 16006        fake      NaN
# 16007   political      NaN
# 16008        fake      NaN
# 16009    reliable  nytimes
# 16010    reliable  nytimes
# 16011   political      NaN
# 16012   political      NaN
# 16013   political      NaN
# 16014    reliable  nytimes
# 16015   clickbait      NaN
# 16016       rumor      NaN
# 16017        fake      NaN
# 16018        fake      NaN
# 16019    reliable  webhose
# 16020        fake      NaN
# 16021        bias      NaN
# 16022    reliable  webhose
# 16023    reliable  nytimes
# 16024        fake      NaN
# 16025   political      NaN
# 16026   political      NaN
# 16027        fake      NaN
# 16028       rumor      NaN
# 16029         NaN      NaN
# 16030        fake      NaN
# 16031    reliable  nytimes
# 16032        fake      NaN
# ...
